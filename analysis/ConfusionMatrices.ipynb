# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
from matplotlib import pyplot as plt

# %run confusion_matrices
#from confusion_matrices import plot_cm, plot_cms

# %%
topic_labels = ['Holy Ghost', 'media', 'priesthood', 'missionary work', 'tithing', 'blessings']
rf_classifications = pd.read_csv("../data/holy_ghost_versus_media_etc_.csv", index_col=0)
y_pred, y_true = rf_classifications["y_pred"].to_numpy(), rf_classifications["y_true"].to_numpy()
rf_cm = confusion_matrix(y_true, y_pred)
plot_cm(rf_cm, topic_labels, "Random Forest Topic Classification")

# %%
topics = ["hope", "home", "missionary work"]
rf_classifications = pd.read_csv("../data/hope_home_missionary_etc_.csv", index_col=0)
y_pred, y_true = rf_classifications["y_pred"].to_numpy(), rf_classifications["y_true"].to_numpy()
rf_cm = confusion_matrix(y_true, y_pred)
plot_cm(rf_cm, topics, "Random Forest Topic Classification")
